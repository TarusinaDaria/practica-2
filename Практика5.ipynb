# %% [markdown]
# <a href="https://colab.research.google.com/github/TarusinaDaria/practica-2/blob/main/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pycocotools
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd 
import os
from pycocotools.coco import COCO
import skimage.io as io
import matplotlib.pyplot as plt
from pathlib import Path

# %%
dataDir=Path('ski/train')
annFile = Path('ski/train/_annotations.coco.json')
coco = COCO(annFile)
imgIds = coco.getImgIds()
# Out:
# loading annotations into memory...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-41-9e8ae9700281> in <cell line: 3>()
#       1 dataDir=Path('ski/train')
#       2 annFile = Path('ski/train/_annotations.coco.json')
# ----> 3 coco = COCO(annFile)
#       4 imgIds = coco.getImgIds()
#       5
#
# /usr/local/lib/python3.10/dist-packages/pycocotools/coco.py in __init__(self, annotation_file)
#      79             print('loading annotations into memory...')
#      80             tic = time.time()
# ---> 81             with open(annotation_file, 'r') as f:
#      82                 dataset = json.load(f)
#      83             assert type(dataset)==dict, 'annotation file format {} not supported'.format(type(dataset))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ski/train/_annotations.coco.json'

# %%
imgs = coco.loadImgs(imgIds[-7:])
_,axs = plt.subplots(len(imgs),2,figsize=(10,5 * len(imgs)))
for img, ax in zip(imgs, axs):
    I = io.imread(dataDir/img['file_name'])
    annIds = coco.getAnnIds(imgIds=[img['id']])
    anns = coco.loadAnns(annIds)
    ax[0].imshow(I)
    ax[1].imshow(I)
    plt.sca(ax[1])
    coco.showAnns(anns, draw_bbox=True)
